# %%
import pymongo
from config import mongo_pass

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = f'mongodb+srv://admin:{mongo_pass}@cluster0.7klhs.mongodb.net/job_data?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

db = client.job_data

# %%
import pandas as pd
import json
df = pd.read_csv ('dataset.csv')
df.reset_index(inplace=True)
df = df[["index","title","worktype","skill","url","formatted_address","country","latlng"]]
df.head(5)
# Out:
#    index                            title   worktype  \
# 0      0              Material Controller  Full-Time
# 1      1          Lead Contracts Engineer  Full-Time
# 2      2                Contract Engineer  Full-Time
# 3      3  Lead Projects Controls Engineer  Full-Time
# 4      4                   Hydrogeologist  Full-Time
#
#                                                skill  \
# 0  ['Warehousing', 'Forklift Truck', 'Housekeeping']
# 1  ['Management', 'Engineering', 'Risk Management...
# 2  ['Management', 'Engineering', 'Risk Management...
# 3  ['Scheduling', 'Finance', 'Accounting', 'Audit...
# 4  ['Groundwater', 'Hydrogeology', 'Geology', 'Wa...
#
#                                                  url    formatted_address  \
# 0  https://www.oilandgasjobsearch.com/job/J3R54K7...   Southaven, MS, USA
# 1  https://www.oilandgasjobsearch.com/job/J3M2HT7...       Ahmadi, Kuwait
# 2  https://www.oilandgasjobsearch.com/job/J3T1F96...       Ahmadi, Kuwait
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4770 entries, 0 to 4769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              4770 non-null   int64
#  1   title              4770 non-null   object
#  2   worktype           4721 non-null   object
#  3   skill              4770 non-null   object
#  4   url                4770 non-null   object
#  5   formatted_address  4770 non-null   object
#  6   country            4770 non-null   object
#  7   latlng             4770 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 298.2+ KB

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4721 entries, 0 to 4769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              4721 non-null   int64
#  1   title              4721 non-null   object
#  2   worktype           4721 non-null   object
#  3   skill              4721 non-null   object
#  4   url                4721 non-null   object
#  5   formatted_address  4721 non-null   object
#  6   country            4721 non-null   object
#  7   latlng             4721 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 331.9+ KB

# %%
import ast

# %%
df["skill"] = df["skill"].apply(lambda x: ast.literal_eval(x))

# %%
df["latlng"] = df["latlng"].apply(lambda x: ast.literal_eval(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4721 entries, 0 to 4769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              4721 non-null   int64
#  1   title              4721 non-null   object
#  2   worktype           4721 non-null   object
#  3   skill              4721 non-null   object
#  4   url                4721 non-null   object
#  5   formatted_address  4721 non-null   object
#  6   country            4721 non-null   object
#  7   latlng             4721 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 331.9+ KB

# %%
records = json.loads(df.T.to_json()).values()

# %%
db.details.insert(records)
# Out:
# C:\Users\khiro\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# [ObjectId('5f7de6bd829f8901b23ec081'),
#  ObjectId('5f7de6bd829f8901b23ec082'),
#  ObjectId('5f7de6bd829f8901b23ec083'),
#  ObjectId('5f7de6bd829f8901b23ec084'),
#  ObjectId('5f7de6bd829f8901b23ec085'),
#  ObjectId('5f7de6bd829f8901b23ec086'),
#  ObjectId('5f7de6bd829f8901b23ec087'),
#  ObjectId('5f7de6bd829f8901b23ec088'),
#  ObjectId('5f7de6bd829f8901b23ec089'),
#  ObjectId('5f7de6bd829f8901b23ec08a'),
#  ObjectId('5f7de6bd829f8901b23ec08b'),
#  ObjectId('5f7de6bd829f8901b23ec08c'),
#  ObjectId('5f7de6bd829f8901b23ec08d'),
#  ObjectId('5f7de6bd829f8901b23ec08e'),
#  ObjectId('5f7de6bd829f8901b23ec08f'),
#  ObjectId('5f7de6bd829f8901b23ec090'),
#  ObjectId('5f7de6bd829f8901b23ec091'),
#  ObjectId('5f7de6bd829f8901b23ec092'),
#  ObjectId('5f7de6bd829f8901b23ec093'),
# ...
